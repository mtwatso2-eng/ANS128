# %% [markdown]
# # Welcome to ANS 128 lab!
#
# We'll be using Google Colab to run the code for labs. Colab uses Jupyter (.ipynb) notebooks to run R and Python.
#
# Create a copy of this Colab notebook and save it wherever you like in your own Google Drive.
#
# Notebooks contain markdown (text) and code in the same document. This is a markdown chunk. Below is a code chunk. Try running the code below using the arrow symbol on the left side!

# %%
"Hello, world!"

# %% [markdown]
# To create a code or text chunk, use the "+ Code" or "+ Text" buttons at the top. Try creating a code chunk below this one!

# %% [markdown]
# Google Colab is really powerful in that provides access via the cloud to CPUs and GPUs that are bigger than most people have, for free. These machines running these, called runtimes, also come with many common packages installed so you don't have to do as much setup.
#
# Check out the different runtime types at `Runtime`->`Change Runtime Type`. Change this runtime to an R runtime with CPU only.

# %% [markdown]
# You do not need to use a paid version of Google Colab for this course, as the free tier will provide enough resources for the assignements and projects. It is worth noting that resources on the free tier are not guaranteed, especially for more powerful runtimes, and your session will end if you close the tab or leave it inactive for more than a few minutes. If this happens, restart the runtime and re-run the code from the beginning.

# %% [markdown]
# # R basics
#
# We will primarily use R in this course, with the exception of Python for image analysis. Let's do a short review of R basics.
#
# The [R basics cheat sheet](https://iqss.github.io/dss-workshops/R/Rintro/base-r-cheat-sheet.pdf) is a good plcae to find most of R's basic syntax.
#
# The code below assigns the contents of the iris default dataset to the object `x`. It then prints the first five rows of x.

# %%
x <- iris

print(head(x))

# %% [markdown]
# Using a `for` loop, how would you get the average of each numeric column in `x`?

# %% [markdown]
# R has powerful plotting capacities using its base functions and packages. For example:

# %%
plot(iris)
# Out:
# plot without title

# %% [markdown]
# Next lab, we'll do a deeper dive into how to manipulate and visualize tabular data in R.

# %% [markdown]
# # GitHub
#
# GitHub is the most common way that data scientists (and other people who write and use code) store and share their code. In this class, you will submit all assignment and project files through GitHub.

# %% [markdown]
# First, you need to make a GitHub account. Name the account using a combination of your UC Davis login and "-ANS128" to create the account. For example, if your login is "mtwatson", name the account "mtwatson-ANS128". This will make it possible for us to find everyone's account easily. If you already have a GitHub account you'd like to use instead, send us an email with a link to it.

# %% [markdown]
# You need to first make a repository to hold your code for this class in Github. Use the `New Repository` button in GitHub to create one. At first only fill in `Repository name` with "ANS128", and select Private.

# %% [markdown]
# ![Screenshot 2025-01-07 at 12.32.39 PM.png](data:image/png;base64,...)

# %% [markdown]
# Add Hao and your TA as collaborators, so they can access the assignments you submit in GitHub. You can find their emails in Canvas.

# %% [markdown]
# ![Screenshot 2025-01-07 at 12.34.48 PM.png](data:image/png;base64,...)

# %% [markdown]
# You can add code and data to GitHub either using the website's point-and-click features or using code with Git. For now, let's add files with point-and-click. To push this notebook to GitHub, first download it as .ipynb using  `File`->`Download`->`Download .ipynb`. Then, add a file in GitHub using the `Upload files` button.

# %% [markdown]
# ![Screenshot 2025-01-07 at 12.54.45 PM.png](data:image/png;base64,...)
